# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dati = pd.read_csv(
    "https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-andamento-nazionale/dpc-covid19-ita-andamento-nazionale.csv"
)
dati["delta_prev_day"] = dati["totale_casi"] - dati["totale_casi"].shift(1)
dati["delta_deceduti_prev_day"] = dati["deceduti"] - dati["deceduti"].shift(1)

dati["delta_delta_prev_day"] = dati["delta_prev_day"] - dati["delta_prev_day"].shift(1)
dati["delta_delta_deceduti_prev_day"] = dati["delta_deceduti_prev_day"] - dati[
    "delta_deceduti_prev_day"
].shift(1)

dati = dati[[
            "totale_casi",
            "delta_prev_day",
            "delta_delta_prev_day",
            "deceduti",
            "delta_deceduti_prev_day",
            "delta_delta_deceduti_prev_day"
        ]]
dati
# Out:
#     totale_casi  delta_prev_day  delta_delta_prev_day  deceduti  \
# 0           229             NaN                   NaN         7
# 1           322            93.0                   NaN        10
# 2           400            78.0                 -15.0        12
# 3           650           250.0                 172.0        17
# 4           888           238.0                 -12.0        21
# 5          1128           240.0                   2.0        29
# 6          1694           566.0                 326.0        34
# 7          2036           342.0                -224.0        52
# 8          2502           466.0                 124.0        79
# 9          3089           587.0                 121.0       107
# 10         3858           769.0                 182.0       148
# 11         4636           778.0                   9.0       197
# 12         5883          1247.0                 469.0       233
# 13         7375          1492.0                 245.0       366
# ...

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
#     val = int(val)
    color = 'red' if val > 0 else 'black'
    return 'color: %s' % color

# %%
s=dati.style.applymap(color_negative_red)
s
# Out:
# <style  type="text/css" >
#     #T_6c39429e_6f14_11ea_868c_0242ac110002row0_col0 {
#             color:  red;
#         }    #T_6c39429e_6f14_11ea_868c_0242ac110002row0_col1 {
#             color:  black;
#         }    #T_6c39429e_6f14_11ea_868c_0242ac110002row0_col2 {
#             color:  black;
#         }    #T_6c39429e_6f14_11ea_868c_0242ac110002row0_col3 {
#             color:  red;
#         }    #T_6c39429e_6f14_11ea_868c_0242ac110002row0_col4 {
#             color:  black;
#         }    #T_6c39429e_6f14_11ea_868c_0242ac110002row0_col5 {
#             color:  black;
#         }    #T_6c39429e_6f14_11ea_868c_0242ac110002row1_col0 {
#             color:  red;
#         }    #T_6c39429e_6f14_11ea_868c_0242ac110002row1_col1 {
#             color:  red;
#         }    #T_6c39429e_6f14_11ea_868c_0242ac110002row1_col2 {
#             color:  black;
#         }    #T_6c39429e_6f14_11ea_868c_0242ac110002row1_col3 {
#             color:  red;
# ...
